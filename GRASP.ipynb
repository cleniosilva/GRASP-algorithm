# %% [markdown]
# ## GRASP Algorithm
# Author: Clênio E Silva
#
# e-mail: clenioeduardo@yahoo.com.br

# %%
import pandas as pd
from random import randint

# %%
matrix = pd.read_csv('bays29.csv', header=None)

# %%
matrix = matrix.iloc[0:,].values.tolist()

# %%
class Grasp:
    def __init__(self, matriz):
        self.matrix = matrix
       
        
    def greedy_Randomized_Construction(self,alpha, seed):
        """
            alpha: define the quality of the elements in RCL
            seed: initial city 
            return solution
        
        """
        self.alpha = alpha
        solution = []
        "add initial city"
        solution.append(seed) 
    
        "add candidates to list "
        CL = list(range(0, len(self.matrix)))
        
        "removing initial city of the candidates list"
        CL.remove(seed) 
        
        "Evaluate the incremental costs of the candidate elements"
        while(CL):
            RCL = {}
            greedy_list = {}
            
            "For all i in CL compute the valor of the greedy funciton"
            for i in CL:
                greedy_list[i] = self.matrix[solution[-1]][i]
                c_min = min(greedy_list.values())
                c_max = max(greedy_list.values())
                
            "build the restricted candidate list (RCL)"
            for k, v in greedy_list.items():
                if k in CL:
                    if v <= (c_min + alpha * (c_max - c_min)):
                        RCL[k] = v
                        
            
            "choose randomly i in LRC"
            keys_list = list(RCL.keys())
            keys_list.sort()
            value = randint(0, len(keys_list)-1)

            candidate = keys_list[value]
            
            solution.append(candidate)
            
            "removing candidate of the CL"
            CL.remove(candidate)
        
        "add first city at the last positon of solution"
        solution.append(solution[0])
          
        
        return solution
     
    
    def __neighborhood_list__(self, s, k):
        """
            s: current solution
            k: size parameter of the neighborhood list
            return: neighborhood_list        
        """
        neighborhood_list = []
        for i in range(len(s)):
            p1 = randint(1, len(s)-2)
            p2 = randint(1, len(s)-2)
            
            si = s
            aux_swap = si[p1]
            si[p1] = si[p2]
            si[p2] = aux_swap
            
            neighborhood_list.append(si)
        
        return neighborhood_list
    
    
    def evaluate_solution(self, solution , matriz):
        """
            solution: current solution
            matriz: distances matrix
            return: f(s) value of fitness
        """
        f = 0
        for i in range(len(solution)-1):
            f += matriz[solution[i]][solution[i+1]]
        
        return f        
    
        
    "Variable Neighborhood Descent (VND)"
    def local_search(self, solution, k_max):
        """
            solution: current solution
            k_max: maximum number of neighborhood list
            return: solution of local search
        """
        s = solution
        k = 1
        
        while(k <= k_max):
            neighborhood_list = self.__neighborhood_list__(s, k)
            
            "find the best neighborhood s' in Nk(s)"
            fitness_value = []
            for i in range(len(neighborhood_list)):
                fitness_value.append(self.evaluate_solution(neighborhood_list[i], self.matrix))
            
            "index of best neighborhood based in fitness value"
            index_best_neighborhood = fitness_value.index(min(fitness_value))
            
            f_line = self.evaluate_solution(neighborhood_list[index_best_neighborhood], self.matrix)
            f = self.evaluate_solution(s , self.matrix)
            
            if (f_line < f):
                s = neighborhood_list[index_best_neighborhood]
                k = 1
            else:
                k += 1
                
        
        return s

# %% [markdown]
# # Run GRASP Algorithm with VND local search
#
# instance Grasp class

# %%
grasp = Grasp( matrix)

# %% [markdown]
# main GRASP algorithm

# %%
seed = randint(0, len(matrix)-1)
max_iterations = 200
current_fitness = 100000
current_solution = []
alpha = 1
k_max = 50


for k in range(max_iterations):
    solution = grasp.greedy_Randomized_Construction(alpha, seed)
    solution = grasp.local_search(solution, k_max)
    
    if(grasp.evaluate_solution(solution, matrix) < current_fitness):
        current_solution = solution
        current_fitness = grasp.evaluate_solution(solution, matrix)
    print("Iteration {}  and current fitness {} ".format(k,current_fitness ))
        
print("Solution {}".format(current_solution))
print("Fitness {}".format(current_fitness))
# Out:
# Iteration 0  and current fitness 4945
# Iteration 1  and current fitness 4945
# Iteration 2  and current fitness 4945
# Iteration 3  and current fitness 4945
# Iteration 4  and current fitness 4945
# Iteration 5  and current fitness 4945
# Iteration 6  and current fitness 4945
# Iteration 7  and current fitness 4945
# Iteration 8  and current fitness 4945
# Iteration 9  and current fitness 4945
# Iteration 10  and current fitness 4945
# Iteration 11  and current fitness 4945
# Iteration 12  and current fitness 4945
# Iteration 13  and current fitness 4945
# Iteration 14  and current fitness 4945
# Iteration 15  and current fitness 4945
# Iteration 16  and current fitness 4945
# Iteration 17  and current fitness 4945
# Iteration 18  and current fitness 4945
# Iteration 19  and current fitness 4945
# Iteration 20  and current fitness 4945
# Iteration 21  and current fitness 4945
# Iteration 22  and current fitness 4945
# Iteration 23  and current fitness 4945
# Iteration 24  and current fitness 4945
# Iteration 25  and current fitness 4945
# Iteration 26  and current fitness 4945
# Iteration 27  and current fitness 4945
# Iteration 28  and current fitness 4945
# Iteration 29  and current fitness 4945
# Iteration 30  and current fitness 4945
# Iteration 31  and current fitness 4945
# Iteration 32  and current fitness 4945
# Iteration 33  and current fitness 4945
# Iteration 34  and current fitness 4945
# Iteration 35  and current fitness 4945
# Iteration 36  and current fitness 4945
# Iteration 37  and current fitness 4945
# Iteration 38  and current fitness 4945
# Iteration 39  and current fitness 4945
# Iteration 40  and current fitness 4945
# Iteration 41  and current fitness 4945
# Iteration 42  and current fitness 4945
# Iteration 43  and current fitness 4945
# Iteration 44  and current fitness 4945
# Iteration 45  and current fitness 4945
# Iteration 46  and current fitness 4945
# Iteration 47  and current fitness 4945
# Iteration 48  and current fitness 4945
# Iteration 49  and current fitness 4945
# Iteration 50  and current fitness 4945
# Iteration 51  and current fitness 4945
# Iteration 52  and current fitness 4945
# Iteration 53  and current fitness 4945
# Iteration 54  and current fitness 4945
# Iteration 55  and current fitness 4945
# Iteration 56  and current fitness 4945
# Iteration 57  and current fitness 4945
# Iteration 58  and current fitness 4945
# Iteration 59  and current fitness 4945
# Iteration 60  and current fitness 4945
# Iteration 61  and current fitness 4945
# Iteration 62  and current fitness 4945
# Iteration 63  and current fitness 4945
# Iteration 64  and current fitness 4945
# Iteration 65  and current fitness 4945
# Iteration 66  and current fitness 4945
# Iteration 67  and current fitness 4945
# Iteration 68  and current fitness 4945
# Iteration 69  and current fitness 4945
# Iteration 70  and current fitness 4945
# Iteration 71  and current fitness 4945
# Iteration 72  and current fitness 4945
# Iteration 73  and current fitness 4945
# Iteration 74  and current fitness 4945
# Iteration 75  and current fitness 4945
# Iteration 76  and current fitness 4945
# Iteration 77  and current fitness 4945
# Iteration 78  and current fitness 4945
# Iteration 79  and current fitness 4945
# Iteration 80  and current fitness 4945
# Iteration 81  and current fitness 4945
# Iteration 82  and current fitness 4945
# Iteration 83  and current fitness 4945
# Iteration 84  and current fitness 4945
# Iteration 85  and current fitness 4945
# Iteration 86  and current fitness 4945
# Iteration 87  and current fitness 4945
# Iteration 88  and current fitness 4945
# Iteration 89  and current fitness 4945
# Iteration 90  and current fitness 4945
# Iteration 91  and current fitness 4945
# Iteration 92  and current fitness 4945
# Iteration 93  and current fitness 4945
# Iteration 94  and current fitness 4945
# Iteration 95  and current fitness 4945
# Iteration 96  and current fitness 4945
# Iteration 97  and current fitness 4945
# Iteration 98  and current fitness 4945
# Iteration 99  and current fitness 4945
# Iteration 100  and current fitness 4945
# Iteration 101  and current fitness 4945
# Iteration 102  and current fitness 4945
# Iteration 103  and current fitness 4945
# Iteration 104  and current fitness 4945
# Iteration 105  and current fitness 4945
# Iteration 106  and current fitness 4945
# Iteration 107  and current fitness 4945
# Iteration 108  and current fitness 4945
# Iteration 109  and current fitness 4945
# Iteration 110  and current fitness 4945
# Iteration 111  and current fitness 4945
# Iteration 112  and current fitness 4945
# Iteration 113  and current fitness 4945
# Iteration 114  and current fitness 4945
# Iteration 115  and current fitness 4945
# Iteration 116  and current fitness 4945
# Iteration 117  and current fitness 4945
# Iteration 118  and current fitness 4945
# Iteration 119  and current fitness 4945
# Iteration 120  and current fitness 4945
# Iteration 121  and current fitness 4945
# Iteration 122  and current fitness 4945
# Iteration 123  and current fitness 4945
# Iteration 124  and current fitness 4945
# Iteration 125  and current fitness 4945
# Iteration 126  and current fitness 4945
# Iteration 127  and current fitness 4945
# Iteration 128  and current fitness 4945
# Iteration 129  and current fitness 4945
# Iteration 130  and current fitness 4945
# Iteration 131  and current fitness 4945
# Iteration 132  and current fitness 4945
# Iteration 133  and current fitness 4945
# Iteration 134  and current fitness 4945
# Iteration 135  and current fitness 4945
# Iteration 136  and current fitness 4945
# Iteration 137  and current fitness 4945
# Iteration 138  and current fitness 4945
# Iteration 139  and current fitness 4945
# Iteration 140  and current fitness 4945
# Iteration 141  and current fitness 4945
# Iteration 142  and current fitness 4945
# Iteration 143  and current fitness 4945
# Iteration 144  and current fitness 4945
# Iteration 145  and current fitness 4945
# Iteration 146  and current fitness 4945
# Iteration 147  and current fitness 4945
# Iteration 148  and current fitness 4945
# Iteration 149  and current fitness 4945
# Iteration 150  and current fitness 4945
# Iteration 151  and current fitness 4945
# Iteration 152  and current fitness 4945
# Iteration 153  and current fitness 4945
# Iteration 154  and current fitness 4945
# Iteration 155  and current fitness 4945
# Iteration 156  and current fitness 4945
# Iteration 157  and current fitness 4945
# Iteration 158  and current fitness 4945
# Iteration 159  and current fitness 4945
# Iteration 160  and current fitness 4945
# Iteration 161  and current fitness 4945
# Iteration 162  and current fitness 4945
# Iteration 163  and current fitness 4945
# Iteration 164  and current fitness 4945
# Iteration 165  and current fitness 4945
# Iteration 166  and current fitness 4945
# Iteration 167  and current fitness 4945
# Iteration 168  and current fitness 4945
# Iteration 169  and current fitness 4945
# Iteration 170  and current fitness 4945
# Iteration 171  and current fitness 4945
# Iteration 172  and current fitness 4945
# Iteration 173  and current fitness 4945
# Iteration 174  and current fitness 4945
# Iteration 175  and current fitness 4945
# Iteration 176  and current fitness 4945
# Iteration 177  and current fitness 4945
# Iteration 178  and current fitness 4945
# Iteration 179  and current fitness 4815
# Iteration 180  and current fitness 4815
# Iteration 181  and current fitness 4815
# Iteration 182  and current fitness 4815
# Iteration 183  and current fitness 4815
# Iteration 184  and current fitness 4815
# Iteration 185  and current fitness 4815
# Iteration 186  and current fitness 4815
# Iteration 187  and current fitness 4815
# Iteration 188  and current fitness 4815
# Iteration 189  and current fitness 4815
# Iteration 190  and current fitness 4815
# Iteration 191  and current fitness 4815
# Iteration 192  and current fitness 4815
# Iteration 193  and current fitness 4815
# Iteration 194  and current fitness 4815
# Iteration 195  and current fitness 4815
# Iteration 196  and current fitness 4815
# Iteration 197  and current fitness 4815
# Iteration 198  and current fitness 4815
# Iteration 199  and current fitness 4815
# Solution [13, 11, 27, 0, 15, 7, 22, 3, 12, 28, 19, 20, 8, 1, 6, 18, 10, 4, 23, 14, 17, 21, 16, 9, 24, 5, 25, 2, 26, 13]
# Fitness 4815

# %% [markdown]
# ![title](GRASP_estrutura.png)

# %% [markdown]
# ![title](GRASP_construcao.png)

# %% [markdown]
# # Variable Neighborhood Descent (VND)
#
# ![title](VND.png)
